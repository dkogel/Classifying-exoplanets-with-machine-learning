# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already satisfied: sklearn in c:\users\dkoge\anaconda3\envs\pythondata38\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\dkoge\anaconda3\envs\pythondata38\lib\site-packages (from sklearn) (0.24.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\dkoge\anaconda3\envs\pythondata38\lib\site-packages (from scikit-learn->sklearn) (1.0.1)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\dkoge\anaconda3\envs\pythondata38\lib\site-packages (from scikit-learn->sklearn) (1.6.2)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\dkoge\anaconda3\envs\pythondata38\lib\site-packages (from scikit-learn->sklearn) (1.20.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dkoge\anaconda3\envs\pythondata38\lib\site-packages (from scikit-learn->sklearn) (2.1.0)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\dkoge\anaconda3\envs\pythondata38\lib\site-packages (1.0.1)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
df = df.dropna()

#Drop rows where a candidate hasn't been declared confirmed or false
df.drop(df[df['koi_disposition'] == 'CANDIDATE'].index, inplace = True)
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Selecting features

# %%
#set target (y-values)
target = df[['koi_disposition']]

# Set features (x-values)
selected_features = df[['koi_fpflag_nt',
                        'koi_fpflag_ss',
                        'koi_fpflag_co',
                        'koi_fpflag_ec', 
                        'koi_period',
                        'koi_time0bk', 
                        'koi_impact',
                        'koi_duration',
                        'koi_depth',
                        'koi_prad',
                        'koi_teq',
                        'koi_insol',
                        'koi_model_snr',
                        'koi_tce_plnt_num',
                        'koi_steff',
                        'koi_slogg',
                        'koi_srad',
                        'ra',
                        'dec',
                        'koi_kepmag']]

# %%
##confirming deletion of "candidate" rows

target_list = target.values
np.unique(target_list)
# Out:
# array(['CONFIRMED', 'FALSE POSITIVE'], dtype=object)

# %% [markdown]
# # Label Encoding

# %%
#reformat data
target = df[['koi_disposition']]
y = target.values.reshape(-1,1)


#label encoding
label_encoder = LabelEncoder()
label_encoder.fit(y)
encoded_targets = label_encoder.transform(y)

encoded_targets
# Out:
# C:\Users\dkoge\anaconda3\envs\PythonData38\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# array([0, 1, 1, ..., 1, 1, 1])

# %% [markdown]
# # Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(selected_features, encoded_targets, random_state= 43)

# %% [markdown]
# # Pre-processing

# %%
# Scale your data with MinMaxScaler


X_scaler = MinMaxScaler().fit(X_train)

X_train_scaled = X_scaler.transform(X_train)

X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
rf = RandomForestClassifier(n_estimators = 1000)
rf = rf.fit(X_train_scaled, y_train)
training_score = rf.score(X_train_scaled, y_train)
test_score = rf.score(X_test_scaled, y_test)

# %%
print(f'Training Score: {training_score}')
print(f'Test Score: {test_score}')
# Out:
# Training Score: 1.0
# Test Score: 0.9894419306184012

# %%
importances = rf.feature_importances_
sorted(zip(rf.feature_importances_, list(selected_features.columns.values)), reverse = True)
# Out:
# [(0.18257799431463212, 'koi_fpflag_co'),
#  (0.1469682702786833, 'koi_fpflag_nt'),
#  (0.1306953111591826, 'koi_fpflag_ss'),
#  (0.11170405536553929, 'koi_prad'),
#  (0.07363980938329014, 'koi_model_snr'),
#  (0.05827644478038467, 'koi_fpflag_ec'),
#  (0.04518453291076131, 'koi_period'),
#  (0.04287324128494685, 'koi_depth'),
#  (0.03877539374324937, 'koi_teq'),
#  (0.03859254404176461, 'koi_insol'),
#  (0.03722279905724088, 'koi_impact'),
#  (0.0197962378467779, 'koi_duration'),
#  (0.018444722596687998, 'koi_time0bk'),
#  (0.010020410329967122, 'koi_steff'),
#  (0.009359239593527363, 'koi_srad'),
#  (0.009211077894028181, 'koi_tce_plnt_num'),
#  (0.00811588349390463, 'koi_slogg'),
#  (0.00773766313798227, 'ra'),
#  (0.0055170785422815624, 'koi_kepmag'),
#  (0.005287290245167826, 'dec')]

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model

n_estimators = [10, 100, 250, 500, 1000, 2000]
criterion= ["gini", "entropy"]
max_depth = [2, 8, 16, 32, 64, 128, 500, 1000]
bootstrap = [True, False]
param_grid = {"n_estimators": n_estimators,
              "criterion": criterion,
              "max_depth": max_depth,
              "bootstrap": bootstrap}

grid = GridSearchCV(rf, param_grid, verbose=3)

# %%
# Train the model with GridSearch

grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=10; total time=   0.0s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=10; total time=   0.0s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=10; total time=   0.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=10; total time=   0.0s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=10; total time=   0.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=100; total time=   0.2s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=100; total time=   0.2s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=100; total time=   0.2s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=100; total time=   0.2s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=100; total time=   0.2s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=250; total time=   0.7s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=250; total time=   0.7s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=250; total time=   0.6s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=250; total time=   0.6s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=250; total time=   0.6s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=500; total time=   1.4s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=500; total time=   1.5s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=500; total time=   1.5s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=500; total time=   1.6s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=500; total time=   1.3s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=1000; total time=   3.1s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=1000; total time=   2.7s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=1000; total time=   3.1s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=1000; total time=   3.1s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=1000; total time=   4.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=2000; total time=   8.3s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=2000; total time=   6.2s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=2000; total time=   5.5s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=2000; total time=   5.7s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=2, n_estimators=2000; total time=   5.5s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=10; total time=   0.0s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=10; total time=   0.0s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=10; total time=   0.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=10; total time=   0.0s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=10; total time=   0.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=100; total time=   0.5s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=100; total time=   0.4s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=100; total time=   0.4s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=100; total time=   0.5s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=100; total time=   0.6s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=250; total time=   1.2s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=250; total time=   1.3s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=250; total time=   1.1s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=250; total time=   1.4s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=250; total time=   1.9s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=500; total time=   3.9s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=500; total time=   2.7s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=500; total time=   2.6s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=500; total time=   2.7s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=500; total time=   2.6s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=1000; total time=   5.4s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=1000; total time=   5.4s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=1000; total time=   5.6s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=1000; total time=   5.4s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=1000; total time=   5.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=2000; total time=  10.7s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=2000; total time=  10.6s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=2000; total time=  11.7s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=2000; total time=  18.3s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=8, n_estimators=2000; total time=  10.9s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=10; total time=   0.0s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=10; total time=   0.0s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=10; total time=   0.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=10; total time=   0.0s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=10; total time=   0.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=100; total time=   0.5s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=100; total time=   0.4s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=100; total time=   0.5s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=100; total time=   0.5s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=100; total time=   0.5s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=250; total time=   1.5s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=250; total time=   1.4s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=250; total time=   1.3s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=250; total time=   1.5s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=250; total time=   1.4s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=500; total time=   2.8s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=500; total time=   2.8s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=500; total time=   2.9s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=500; total time=   2.8s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=500; total time=   3.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=1000; total time=   6.0s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=1000; total time=   5.7s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=1000; total time=   6.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=1000; total time=   5.9s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=1000; total time=   5.6s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=2000; total time=  12.0s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=2000; total time=  11.2s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=2000; total time=  12.8s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=2000; total time=  19.0s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=16, n_estimators=2000; total time=  11.8s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=10; total time=   0.0s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=10; total time=   0.0s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=10; total time=   0.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=10; total time=   0.0s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=10; total time=   0.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=100; total time=   0.6s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=100; total time=   0.5s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=100; total time=   0.6s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=100; total time=   0.5s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=100; total time=   0.5s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=250; total time=   1.4s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=250; total time=   1.4s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=250; total time=   1.3s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=250; total time=   1.4s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=250; total time=   1.4s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=500; total time=   3.2s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=500; total time=   2.7s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=500; total time=   2.9s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=500; total time=   3.6s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=500; total time=   2.8s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=1000; total time=   5.9s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=1000; total time=   5.8s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=1000; total time=   6.3s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=1000; total time=   5.4s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=1000; total time=   6.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=2000; total time=  12.1s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=2000; total time=  11.9s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=2000; total time=  19.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=2000; total time=  12.6s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=32, n_estimators=2000; total time=  12.7s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=10; total time=   0.0s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=10; total time=   0.0s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=10; total time=   0.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=10; total time=   0.0s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=10; total time=   0.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=100; total time=   0.4s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=100; total time=   0.5s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=100; total time=   0.5s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=100; total time=   0.5s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=100; total time=   0.4s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=250; total time=   1.4s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=250; total time=   1.5s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=250; total time=   1.4s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=250; total time=   1.5s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=250; total time=   1.3s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=500; total time=   2.8s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=500; total time=   2.6s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=500; total time=   2.8s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=500; total time=   3.0s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=500; total time=   2.8s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=1000; total time=   5.9s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=1000; total time=   5.8s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=1000; total time=   6.2s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=1000; total time=   6.0s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=1000; total time=   5.9s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=2000; total time=  12.4s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=2000; total time=  11.8s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=2000; total time=  18.9s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=2000; total time=  11.8s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=64, n_estimators=2000; total time=  14.9s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=10; total time=   0.0s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=10; total time=   0.0s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=10; total time=   0.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=10; total time=   0.0s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=10; total time=   0.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=100; total time=   0.6s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=100; total time=   0.7s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=100; total time=   0.6s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=100; total time=   0.5s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=100; total time=   0.7s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=250; total time=   1.6s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=250; total time=   1.4s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=250; total time=   1.4s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=250; total time=   1.4s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=250; total time=   1.4s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=500; total time=   2.9s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=500; total time=   2.6s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=500; total time=   3.1s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=500; total time=   3.1s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=500; total time=   3.1s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=1000; total time=   5.6s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=1000; total time=   5.6s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=1000; total time=   5.7s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=1000; total time=   5.7s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=1000; total time=   5.9s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=2000; total time=  12.1s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=2000; total time=  16.7s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=2000; total time=  14.6s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=2000; total time=  11.9s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=128, n_estimators=2000; total time=  11.7s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=10; total time=   0.0s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=10; total time=   0.0s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=10; total time=   0.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=10; total time=   0.0s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=10; total time=   0.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=100; total time=   0.4s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=100; total time=   0.5s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=100; total time=   0.5s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=100; total time=   0.5s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=100; total time=   0.4s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=250; total time=   1.2s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=250; total time=   1.3s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=250; total time=   1.4s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=250; total time=   1.4s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=250; total time=   1.3s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=500; total time=   2.9s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=500; total time=   2.7s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=500; total time=   3.1s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=500; total time=   2.8s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=500; total time=   2.9s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=1000; total time=   5.9s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=1000; total time=   6.0s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=1000; total time=   6.2s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=1000; total time=   5.6s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=1000; total time=   6.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=2000; total time=  12.2s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=2000; total time=  20.0s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=2000; total time=  12.3s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=2000; total time=  11.8s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=500, n_estimators=2000; total time=  12.2s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=10; total time=   0.0s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=10; total time=   0.0s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=10; total time=   0.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=10; total time=   0.0s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=10; total time=   0.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=100; total time=   0.5s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=100; total time=   0.4s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=100; total time=   0.5s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=100; total time=   0.5s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=100; total time=   0.5s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=250; total time=   1.8s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=250; total time=   1.5s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=250; total time=   1.4s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=250; total time=   1.4s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=250; total time=   1.3s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=500; total time=   3.0s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=500; total time=   2.8s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=500; total time=   3.2s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=500; total time=   2.7s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=500; total time=   2.9s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=1000; total time=   5.9s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=1000; total time=   5.8s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=1000; total time=   6.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=1000; total time=   6.2s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=1000; total time=   6.2s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=2000; total time=  13.5s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=2000; total time=  17.3s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=2000; total time=  12.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=2000; total time=  12.0s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=1000, n_estimators=2000; total time=  11.8s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=10; total time=   0.0s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=10; total time=   0.0s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=10; total time=   0.0s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=10; total time=   0.0s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=10; total time=   0.0s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=100; total time=   0.2s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=100; total time=   0.3s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=100; total time=   0.3s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=100; total time=   0.3s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=100; total time=   0.3s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=250; total time=   0.8s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=250; total time=   0.8s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=250; total time=   0.8s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=250; total time=   0.7s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=250; total time=   0.9s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=500; total time=   1.7s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=500; total time=   1.6s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=500; total time=   1.6s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=500; total time=   1.7s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=500; total time=   1.5s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=1000; total time=   3.5s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=1000; total time=   3.4s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=1000; total time=   3.4s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=1000; total time=   3.6s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=1000; total time=   3.4s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=2000; total time=   6.8s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=2000; total time=   6.9s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=2000; total time=   6.5s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=2000; total time=   6.9s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=2, n_estimators=2000; total time=  12.6s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=10; total time=   0.1s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=10; total time=   0.1s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=10; total time=   0.2s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=10; total time=   0.1s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=10; total time=   0.1s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=100; total time=   1.7s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=100; total time=   1.0s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=100; total time=   0.8s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=100; total time=   0.6s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=100; total time=   0.7s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=250; total time=   1.8s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=250; total time=   1.6s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=250; total time=   1.7s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=250; total time=   1.6s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=250; total time=   1.6s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=500; total time=   3.4s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=500; total time=   3.2s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=500; total time=   3.3s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=500; total time=   3.4s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=500; total time=   3.2s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=1000; total time=   6.9s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=1000; total time=   6.8s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=1000; total time=   7.2s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=1000; total time=   6.6s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=1000; total time=   6.6s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=2000; total time=  13.8s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=2000; total time=  13.2s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=2000; total time=  13.4s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=2000; total time=  21.9s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=8, n_estimators=2000; total time=  13.9s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=10; total time=   0.0s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=10; total time=   0.0s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=10; total time=   0.0s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=10; total time=   0.0s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=10; total time=   0.0s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=100; total time=   0.7s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=100; total time=   0.8s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=100; total time=   0.7s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=100; total time=   0.6s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=100; total time=   0.7s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=250; total time=   1.9s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=250; total time=   1.9s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=250; total time=   1.9s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=250; total time=   1.8s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=250; total time=   1.9s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=500; total time=   3.8s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=500; total time=   3.7s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=500; total time=   5.2s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=500; total time=   3.8s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=500; total time=   4.0s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=1000; total time=   7.3s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=1000; total time=   6.9s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=1000; total time=   7.1s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=1000; total time=   6.7s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=1000; total time=   7.4s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=2000; total time=  14.1s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=2000; total time=  23.5s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=2000; total time=  14.5s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=2000; total time=  14.7s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=16, n_estimators=2000; total time=  14.7s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=10; total time=   0.0s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=10; total time=   0.0s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=10; total time=   0.0s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=10; total time=   0.0s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=10; total time=   0.0s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=100; total time=   0.6s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=100; total time=   0.5s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=100; total time=   0.7s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=100; total time=   0.7s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=100; total time=   0.6s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=250; total time=   1.7s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=250; total time=   1.6s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=250; total time=   1.9s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=250; total time=   1.6s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=250; total time=   1.7s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=500; total time=   3.4s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=500; total time=   3.2s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=500; total time=   3.8s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=500; total time=   3.5s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=500; total time=   3.6s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=1000; total time=   7.1s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=1000; total time=   6.9s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=1000; total time=   7.7s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=1000; total time=  15.5s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=1000; total time=   7.3s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=2000; total time=  14.1s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=2000; total time=  13.9s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=2000; total time=  14.7s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=2000; total time=  14.2s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=32, n_estimators=2000; total time=  14.0s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=10; total time=   0.0s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=10; total time=   0.0s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=10; total time=   0.0s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=10; total time=   0.0s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=10; total time=   0.0s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=100; total time=   0.5s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=100; total time=   0.6s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=100; total time=   0.6s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=100; total time=   0.5s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=100; total time=   0.6s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=250; total time=   1.6s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=250; total time=   1.9s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=250; total time=   1.7s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=250; total time=   1.8s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=250; total time=   1.8s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=500; total time=   3.6s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=500; total time=   3.5s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=500; total time=   3.6s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=500; total time=   5.1s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=500; total time=   9.5s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=1000; total time=   7.9s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=1000; total time=   7.1s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=1000; total time=   7.3s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=1000; total time=   7.2s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=1000; total time=   7.2s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=2000; total time=  14.4s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=2000; total time=  13.7s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=2000; total time=  14.8s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=2000; total time=  14.2s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=64, n_estimators=2000; total time=  17.7s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=10; total time=   0.1s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=10; total time=   0.1s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=10; total time=   0.1s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=10; total time=   0.1s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=10; total time=   0.1s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=100; total time=   2.1s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=100; total time=   1.9s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=100; total time=   1.8s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=100; total time=   0.9s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=100; total time=   0.9s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=250; total time=   2.0s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=250; total time=   1.6s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=250; total time=   1.6s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=250; total time=   1.6s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=250; total time=   1.8s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=500; total time=   3.5s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=500; total time=   3.5s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=500; total time=   3.5s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=500; total time=   3.4s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=500; total time=   3.4s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=1000; total time=   7.1s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=1000; total time=   6.8s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=1000; total time=   7.3s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=1000; total time=   6.9s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=1000; total time=   7.2s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=2000; total time=  14.5s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=2000; total time=  14.1s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=2000; total time=  14.8s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=2000; total time=  21.9s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=128, n_estimators=2000; total time=  14.2s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=10; total time=   0.0s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=10; total time=   0.0s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=10; total time=   0.0s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=10; total time=   0.0s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=10; total time=   0.0s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=100; total time=   0.5s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=100; total time=   0.5s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=100; total time=   0.8s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=100; total time=   0.6s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=100; total time=   0.6s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=250; total time=   1.6s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=250; total time=   1.8s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=250; total time=   1.6s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=250; total time=   1.7s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=250; total time=   1.7s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=500; total time=   3.5s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=500; total time=   3.3s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=500; total time=   3.3s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=500; total time=   3.4s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=500; total time=   3.6s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=1000; total time=   7.1s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=1000; total time=   7.2s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=1000; total time=   7.2s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=1000; total time=   6.8s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=1000; total time=   7.2s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=2000; total time=  14.8s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=2000; total time=  22.3s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=2000; total time=  14.4s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=2000; total time=  14.4s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=500, n_estimators=2000; total time=  14.3s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=10; total time=   0.0s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=10; total time=   0.0s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=10; total time=   0.0s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=10; total time=   0.0s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=10; total time=   0.0s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=100; total time=   0.5s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=100; total time=   0.6s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=100; total time=   0.6s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=100; total time=   0.6s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=100; total time=   0.7s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=250; total time=   1.6s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=250; total time=   1.7s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=250; total time=   1.8s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=250; total time=   1.7s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=250; total time=   1.5s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=500; total time=   3.6s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=500; total time=   3.4s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=500; total time=   3.4s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=500; total time=   3.4s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=500; total time=   3.5s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=1000; total time=   7.0s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=1000; total time=   6.9s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=1000; total time=   7.8s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=1000; total time=  15.0s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=1000; total time=   8.2s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=2000; total time=  15.2s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=2000; total time=  14.4s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=2000; total time=  14.4s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=2000; total time=  14.6s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_depth=1000, n_estimators=2000; total time=  14.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=2, n_estimators=10; total time=   0.0s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=2, n_estimators=10; total time=   0.0s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=2, n_estimators=10; total time=   0.0s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=2, n_estimators=10; total time=   0.0s
# [CV 5/5] END bootstrap=False, criterion=gini, max_depth=2, n_estimators=10; total time=   0.0s
# [CV 1/5] END bootstrap=False, criterion=gini, max_depth=2, n_estimators=100; total time=   0.3s
# [CV 2/5] END bootstrap=False, criterion=gini, max_depth=2, n_estimators=100; total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=gini, max_depth=2, n_estimators=100; total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_depth=2, n_estimators=100; total time=   0.2s
# ...
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=16, n_estimators=2000; total time=  26.9s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=16, n_estimators=2000; total time=  20.5s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=16, n_estimators=2000; total time=  31.1s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=16, n_estimators=2000; total time=  20.4s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=10; total time=   0.0s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=10; total time=   0.0s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=10; total time=   0.0s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=10; total time=   0.0s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=10; total time=   0.0s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=100; total time=   1.0s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=100; total time=   1.0s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=100; total time=   1.1s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=100; total time=   1.1s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=100; total time=   1.9s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=250; total time=   7.0s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=250; total time=   6.3s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=250; total time=   3.5s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=250; total time=   2.8s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=250; total time=   2.5s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=500; total time=   4.8s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=500; total time=   5.0s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=500; total time=   5.0s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=500; total time=   5.3s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=500; total time=   5.0s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=1000; total time=  10.6s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=1000; total time=  20.4s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=1000; total time=  11.6s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=1000; total time=  10.7s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=1000; total time=  10.4s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=2000; total time=  31.6s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=2000; total time=  20.9s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=2000; total time=  28.1s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=2000; total time=  24.1s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=32, n_estimators=2000; total time=  22.9s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=10; total time=   0.2s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=10; total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=10; total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=10; total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=10; total time=   0.1s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=100; total time=   2.6s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=100; total time=   2.6s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=100; total time=   2.6s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=100; total time=   2.5s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=100; total time=   1.4s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=250; total time=   3.0s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=250; total time=   2.5s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=250; total time=   2.6s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=250; total time=   2.3s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=250; total time=   2.3s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=500; total time=   5.8s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=500; total time=   5.6s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=500; total time=   5.6s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=500; total time=   5.3s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=500; total time=   4.8s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=1000; total time=  17.4s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=1000; total time=  16.7s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=1000; total time=  12.9s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=1000; total time=  11.1s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=1000; total time=  19.1s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=2000; total time=  22.3s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=2000; total time=  22.7s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=2000; total time=  33.6s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=2000; total time=  21.4s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=64, n_estimators=2000; total time=  39.3s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=10; total time=   0.1s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=10; total time=   0.1s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=10; total time=   0.1s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=10; total time=   0.0s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=10; total time=   0.1s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=100; total time=   1.1s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=100; total time=   0.9s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=100; total time=   1.2s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=100; total time=   0.9s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=100; total time=   1.1s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=250; total time=   2.7s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=250; total time=   2.5s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=250; total time=   2.5s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=250; total time=   2.9s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=250; total time=   2.9s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=500; total time=   7.4s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=500; total time=  11.1s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=500; total time=  11.6s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=500; total time=   5.3s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=500; total time=   5.0s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=1000; total time=  10.6s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=1000; total time=  14.5s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=1000; total time=  12.2s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=1000; total time=   9.9s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=1000; total time=  10.3s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=2000; total time=  21.0s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=2000; total time=  41.9s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=2000; total time=  21.1s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=2000; total time=  22.0s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=128, n_estimators=2000; total time=  22.7s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=10; total time=   0.0s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=10; total time=   0.0s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=10; total time=   0.0s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=10; total time=   0.0s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=10; total time=   0.0s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=100; total time=   0.9s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=100; total time=   1.0s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=100; total time=   0.9s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=100; total time=   1.0s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=100; total time=   1.0s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=250; total time=   2.8s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=250; total time=   2.6s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=250; total time=   2.8s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=250; total time=   2.6s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=250; total time=   4.8s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=500; total time=  12.8s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=500; total time=  11.6s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=500; total time=   8.7s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=500; total time=   5.5s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=500; total time=   5.6s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=1000; total time=  11.4s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=1000; total time=  20.3s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=1000; total time=  11.2s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=1000; total time=  11.1s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=1000; total time=  11.0s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=2000; total time=  32.8s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=2000; total time=  34.4s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=2000; total time=  42.4s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=2000; total time=  22.9s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=500, n_estimators=2000; total time=  27.8s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=10; total time=   0.0s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=10; total time=   0.0s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=10; total time=   0.0s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=10; total time=   0.0s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=10; total time=   0.0s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=100; total time=   0.9s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=100; total time=   0.9s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=100; total time=   1.0s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=100; total time=   1.0s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=100; total time=   1.0s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=250; total time=   2.6s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=250; total time=   2.6s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=250; total time=   2.8s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=250; total time=   2.4s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=250; total time=   2.6s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=500; total time=  10.8s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=500; total time=  13.2s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=500; total time=  15.5s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=500; total time=  10.8s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=500; total time=   6.8s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=1000; total time=  14.7s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=1000; total time=  19.6s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=1000; total time=   9.9s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=1000; total time=  15.2s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=1000; total time=  18.3s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=2000; total time=  29.1s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=2000; total time=  34.7s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=2000; total time=  26.8s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=2000; total time=  27.4s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=1000, n_estimators=2000; total time=  27.8s
# GridSearchCV(estimator=RandomForestClassifier(n_estimators=1000),
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 8, 16, 32, 64, 128, 500, 1000],
#                          'n_estimators': [10, 100, 250, 500, 1000, 2000]},
#              verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 16, 'n_estimators': 1000}
# 0.9904487848045258

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'your_name.sav'
joblib.dump(your_model, filename)
